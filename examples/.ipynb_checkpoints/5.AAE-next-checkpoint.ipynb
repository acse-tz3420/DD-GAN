# %% [markdown]
# ===================================================
# ## 5. AAE-next
# #### AAE trained to predict the next time level $\alpha_{n+1} = f(\alpha_n)$
#
# #### Tianyi Zhao
# ===================================================

# %%
# %%javascript
# IPython.notebook.kernel.execute(`notebookName = '${IPython.notebook.notebook_name}'`)

# %%
notebookName
# Out:
# '5.AAE-next.ipynb'

# %% [raw]
# notebookName = 'AAE-next.ipynb'

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import time

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
tf.random.set_seed(42)
seed(42)

# %%
value = tf.test.is_gpu_available(
    cuda_only=False,
    min_cuda_compute_capability=None
)
print ('***If TF can access GPU: ***\n',value) # MUST RETURN True IF IT CAN!!
print('\n')
print("***Num GPUs Available: ***\n", len(tf.config.experimental.list_physical_devices('GPU')))

tf.config.set_soft_device_placement(True)

gpus = tf.config.experimental.list_physical_devices('GPU')
# Out:
# WARNING:tensorflow:From <ipython-input-7-a4df3c637838>:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# ***If TF can access GPU: ***
#  True
#
#
# ***Num GPUs Available: ***
#  1

# %% [markdown]
# ## Load data

# %%
data_dir = './../data/preprocessed/single_domain/'
pod_coeffs = np.load(data_dir + 'pod_coeffs_1.npy') 
pod_coeffs.shape
# Out:
# (1, 10, 1999)

# %%
npod = 5
X_pod = np.transpose(pod_coeffs.reshape(10, 1999)[:npod])
step = 0.25
times = np.arange(0, len(X_pod), step, dtype="float64")

X_pod.shape
# Out:
# (1999, 5)

# %%
fig, ax = plt.subplots(1,1, figsize=[15,3])
ax.plot(times[0:500], X_pod[0:500]);
ax.grid()
ax.legend(range(5),loc='lower left')

# %% [markdown]
# ## Prepare data

# %%
X_train = np.concatenate((X_pod[:-3], X_pod[1:-2], X_pod[2:-1], X_pod[3:]), axis=1)
X_train.shape
# Out:
# (1996, 20)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

X_train_scaled = scaler.fit_transform(X_train)
np.allclose(X_train, scaler.inverse_transform(X_train_scaled))
# Out:
# True

# %%
nderiv = 3
x_train = X_train_scaled[:, :nderiv*npod]
y_train = X_train_scaled[:, -npod:]
print(x_train.shape, y_train.shape)
# Out:
# (1996, 15) (1996, 5)

# %% [markdown]
# ## Train the AAE

# %% [raw]
# !pip install wandb

# %%
import wandb

# Initialize a new run and set hyperparameters
#wandb.login(key='356a5933239117f23bf9483081f3ca58e5efbe8b')  #Use this key to log in
wandb.init(project='tsp-ai', group='aae', entity='tinayzh')
wandb.watch_called = False  # Re-run the model without restarting the runtime, unnecessary after our next release

# config is a variable that holds and saves hyper parameters and inputs
config = wandb.config  # Initialize config

config.datagroup = 'new' #'new_submean'
config.npod = npod
config.ndomain = 1
config.nderiv_order = 0
#config.ntimes = ntimes # Consecutive times for the GAN
#config.ntime_step = level_step # step between time levels

#config.seed = 42  # random seed(default:42)
config.batch_size = 16  # input batch size for training (default:64)
config.latent_space = 100

config.architechture = 'AAE_deriv_sigmoid'
config.dropout = 0
config.activate = 'sigmoid'
config.optimizer = 'Nadam'
config.lr = 1e-4  # learning rate(default:0.01)

config.epochs = 200  # number of epochs to train(default:10)
#config.no_cuda = False  # disables CUDA training
config.log_interval = 10  # how many batches to wait before logging training status
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: tinayzh (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">good-armadillo-38</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/tinayzh/tsp-ai" target="_blank">https://wandb.ai/tinayzh/tsp-ai</a><br/>
#                 Run page: <a href="https://wandb.ai/tinayzh/tsp-ai/runs/2xkr0nur" target="_blank">https://wandb.ai/tinayzh/tsp-ai/runs/2xkr0nur</a><br/>
#                 Run data is saved locally in <code>/cloud/aae/examples/wandb/run-20210824_105423-2xkr0nur</code><br/><br/>

# %%
batch_size = config.batch_size
latent_space = config.latent_space
dropout = config.dropout
activate = config.activate
lr = config.lr
epochs = config.epochs

# %%
import sys
sys.path.append("..")

# Built package imports
from PredAAE.models import Predictive_adversarial
from PredAAE.architectures.cae.D2 import *
from PredAAE.architectures.svdae import *
from PredAAE.architectures.discriminators import *

# %%
initializer = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, seed=None)
optimizer = tf.keras.optimizers.Nadam(learning_rate=lr)
#optimizer = tf.keras.optimizers.Nadam(learning_rate=0.0005, beta_1=0.98, beta_2=0.99999)

encoder, decoder = build_deriv_encoder_decoder(npod, latent_space, initializer, 
                                                  dropout=dropout, reg=0, final_act=activate, info=False)
discriminator = build_custom_discriminator(latent_space, initializer, info=False)

# %%
pred_aae = Predictive_adversarial(encoder, decoder, discriminator, optimizer)
pred_aae.compile(npod)

# %%
encoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8192)              122880
# _________________________________________________________________
# dropout (Dropout)            (None, 8192)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 8192)              32768
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 8, 8, 128)         147456
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 4, 4, 128)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 4, 4, 64)          73728
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 64)          256
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               25600
# =================================================================
# Total params: 403,200
# Trainable params: 386,432
# Non-trainable params: 16,768
# _________________________________________________________________

# %%
decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 256)               25600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 2, 2, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 2, 2, 64)          36864
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 4, 4, 64)          0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 128)         73728
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 40960
# =================================================================
# Total params: 178,944
# Trainable params: 178,048
# Non-trainable params: 896
# _________________________________________________________________

# %%
discriminator.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               50500
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 501
# =================================================================
# Total params: 61,101
# Trainable params: 0
# Non-trainable params: 61,101
# _________________________________________________________________

# %% [raw]
# def train_preprocessed(self, x_full, y_full, epochs, interval=5,
#                            val_size=0, val_data=None,
#                            batch_size=128, val_batch_size=128, wandb_log=False,
#                            n_discriminator=5, n_gradient_ascent=np.inf, noise_std=0):

# %%
with tf.device("/gpu:0"):
    hist = pred_aae.train_preprocessed(x_train, y_train, epochs=epochs, val_size=0.1, 
                                       batch_size=batch_size, wandb_log=True, n_discriminator=1)
# Out:
# Epoch 1/200
# discriminator train_loss: 0.320084 - generator train_loss: 0.074837 - discriminator val_loss: 0.070300 - generator val_loss: 0.114685 - 19s
# Epoch 2/200
# discriminator train_loss: 0.054630 - generator train_loss: 0.047676 - discriminator val_loss: 0.017851 - generator val_loss: 0.079035 - 10s
# Epoch 3/200
# discriminator train_loss: 0.038229 - generator train_loss: 0.029523 - discriminator val_loss: 0.010450 - generator val_loss: 0.073433 - 10s
# Epoch 4/200
# discriminator train_loss: 0.036489 - generator train_loss: 0.022021 - discriminator val_loss: 0.009201 - generator val_loss: 0.041851 - 11s
# Epoch 5/200
# discriminator train_loss: 0.035857 - generator train_loss: 0.015154 - discriminator val_loss: 0.009480 - generator val_loss: 0.011581 - 10s
# Epoch 6/200
# discriminator train_loss: 0.035955 - generator train_loss: 0.012735 - discriminator val_loss: 0.008457 - generator val_loss: 0.010390 - 11s
# Epoch 7/200
# discriminator train_loss: 0.036006 - generator train_loss: 0.011677 - discriminator val_loss: 0.009248 - generator val_loss: 0.007683 - 10s
# Epoch 8/200
# discriminator train_loss: 0.035645 - generator train_loss: 0.011013 - discriminator val_loss: 0.008466 - generator val_loss: 0.008312 - 11s
# Epoch 9/200
# discriminator train_loss: 0.036151 - generator train_loss: 0.010695 - discriminator val_loss: 0.007550 - generator val_loss: 0.010504 - 11s
# Epoch 10/200
# discriminator train_loss: 0.035549 - generator train_loss: 0.009318 - discriminator val_loss: 0.007388 - generator val_loss: 0.008116 - 21s
# Epoch 11/200
# discriminator train_loss: 0.035194 - generator train_loss: 0.009000 - discriminator val_loss: 0.007159 - generator val_loss: 0.007910 - 11s
# Epoch 12/200
# discriminator train_loss: 0.034813 - generator train_loss: 0.009346 - discriminator val_loss: 0.007044 - generator val_loss: 0.010913 - 10s
# Epoch 13/200
# discriminator train_loss: 0.035312 - generator train_loss: 0.008416 - discriminator val_loss: 0.007454 - generator val_loss: 0.006354 - 10s
# Epoch 14/200
# discriminator train_loss: 0.035462 - generator train_loss: 0.008428 - discriminator val_loss: 0.008059 - generator val_loss: 0.007608 - 11s
# Epoch 15/200
# discriminator train_loss: 0.035093 - generator train_loss: 0.007763 - discriminator val_loss: 0.008533 - generator val_loss: 0.006042 - 10s
# Epoch 16/200
# discriminator train_loss: 0.035471 - generator train_loss: 0.007791 - discriminator val_loss: 0.007752 - generator val_loss: 0.006249 - 11s
# Epoch 17/200
# discriminator train_loss: 0.034946 - generator train_loss: 0.007708 - discriminator val_loss: 0.007383 - generator val_loss: 0.005934 - 21s
# Epoch 18/200
# discriminator train_loss: 0.034691 - generator train_loss: 0.007834 - discriminator val_loss: 0.008198 - generator val_loss: 0.006054 - 21s
# Epoch 19/200
# discriminator train_loss: 0.035132 - generator train_loss: 0.007447 - discriminator val_loss: 0.007960 - generator val_loss: 0.006558 - 11s
# Epoch 20/200
# discriminator train_loss: 0.034581 - generator train_loss: 0.007667 - discriminator val_loss: 0.007965 - generator val_loss: 0.008388 - 11s
# Epoch 21/200
# discriminator train_loss: 0.035080 - generator train_loss: 0.007459 - discriminator val_loss: 0.007653 - generator val_loss: 0.007214 - 11s
# Epoch 22/200
# discriminator train_loss: 0.034972 - generator train_loss: 0.007619 - discriminator val_loss: 0.008630 - generator val_loss: 0.006394 - 11s
# Epoch 23/200
# discriminator train_loss: 0.036467 - generator train_loss: 0.007043 - discriminator val_loss: 0.009282 - generator val_loss: 0.006618 - 11s
# Epoch 24/200
# discriminator train_loss: 0.035482 - generator train_loss: 0.006878 - discriminator val_loss: 0.008896 - generator val_loss: 0.005937 - 10s
# Epoch 25/200
# discriminator train_loss: 0.035676 - generator train_loss: 0.007050 - discriminator val_loss: 0.008906 - generator val_loss: 0.005930 - 11s
# Epoch 26/200
# discriminator train_loss: 0.032993 - generator train_loss: 0.005353 - discriminator val_loss: 0.007176 - generator val_loss: 0.005065 - 11s
# Epoch 195/200
# discriminator train_loss: 0.032944 - generator train_loss: 0.005507 - discriminator val_loss: 0.006854 - generator val_loss: 0.005192 - 11s
# Epoch 196/200
# discriminator train_loss: 0.033067 - generator train_loss: 0.005341 - discriminator val_loss: 0.007546 - generator val_loss: 0.005054 - 12s
# Epoch 197/200
# discriminator train_loss: 0.033401 - generator train_loss: 0.005494 - discriminator val_loss: 0.007886 - generator val_loss: 0.005281 - 12s
# Epoch 198/200
# discriminator train_loss: 0.033037 - generator train_loss: 0.005513 - discriminator val_loss: 0.007713 - generator val_loss: 0.005173 - 11s
# Epoch 199/200
# discriminator train_loss: 0.032829 - generator train_loss: 0.005375 - discriminator val_loss: 0.007484 - generator val_loss: 0.005145 - 12s
# Epoch 200/200
# discriminator train_loss: 0.033077 - generator train_loss: 0.005352 - discriminator val_loss: 0.007384 - generator val_loss: 0.005848 - 11s

# %%
fig, ax = plt.subplots(2, 1, figsize=[20,10])
ax[0].plot(hist[:, 0])
ax[0].plot(hist[:, 2])
ax[0].legend(['train_loss_G', 'train_loss_D'])
ax[0].set_yscale('log')
ax[0].grid()

ax[1].plot(hist[:, 1])
ax[1].plot(hist[:, 3])
ax[1].legend(['val_loss_G', 'val_loss_D'])
ax[1].set_yscale('log')
ax[1].grid()

# %%
import joblib
joblib.dump(scaler, "models/scaler-next_arch_sigm.pkl")
#encoder.save("models/encoder-deriv-3.h5")
#decoder.save("models/decoder-deriv-3.h5")
#discriminator.save("models/discriminator-deriv-3.h5")
pred_aae.save(dirname="models/next_arch_sigm")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: models/next_arch_sigm/encoder/assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: models/next_arch_sigm/decoder/assets
# INFO:tensorflow:Assets written to: models/next_arch_sigm/discriminator/assets

# %% [markdown]
# ## Predict one next time level

# %%
result = pred_aae.adversarial_autoencoder.predict(x_train)
result[0].shape
#result_new = result[0]
# Out:
# (1996, 5)

# %%
X_true = y_train
X_pred = result[0]

# %%
# calculate RMSE
pred_mse = np.mean(tf.keras.losses.MSE(X_true, X_pred))
pred_rmse = np.sqrt(pred_mse)
#config.prediction_rmse = pred_rmse
print('Prediction RMSE: %.4f' % pred_rmse)
# Out:
# Prediction RMSE: 0.0322

# %% [markdown]
# ### Calculate next time level

# %%
X_generated = np.concatenate((x_train, X_pred), axis=1)
X_generated.shape
# Out:
# (1996, 20)

# %%
X_generated = scaler.inverse_transform(X_generated)

# %%
# Calculate the predicted value of the next time step
# a_n
X_0 = X_generated[:, :5]
# a_n+1
X_1 = X_generated[:, 5:10]
# a_n+2
X_2 = X_generated[:, 10:15]
# a_n+3
X_3 = X_generated[:, 15:20]

# %%
fig, ax = plt.subplots(5,1, figsize=[15,10])
for i in range(5):
    ax.flatten()[i].plot(X_3[:-3,i])
    ax.flatten()[i].plot(X_0[3:,i], alpha=0.9)

# %%
X_true = X_0[3:]
X_pred = X_3[:-3]

# %%
# calculate RMSE
pred_mse = np.mean(tf.keras.losses.MSE(X_true, X_pred))
pred_rmse = np.sqrt(pred_mse)
#config.prediction_rmse = pred_rmse
print('Prediction RMSE: %.4f' % pred_rmse)
# Out:
# Prediction RMSE: 0.0551

# %% [markdown]
# ## Predict multiple points
# In this section we predict multiple points. We use the last predictions as the points to data assimilate in the next prediction.

# %% [raw]
# from tensorflow.keras.models import load_model
# import joblib
#
# #model_name = 'models/aae-deriv-3.h5'
# #encoder = load_model('./{model_name}'.format(model_name=model_name)).layers
# encoder = load_model('./models/aae-deriv-3.h5'.format(model_name=model_name)).layers
# decoder = load_model('./models/aae-deriv-3.h5'.format(model_name=model_name)).layers
# discriminator = load_model('./models/aae-deriv-3.h5'.format(model_name=model_name)).layers
# scaler = joblib.load("models/scaler-aae-deriv-3.pkl")

# %%
def predict_next_time_level(x_test, nstep, npredict):
    y_predall = []
    for i in range(npredict):
        yhat = pred_aae.adversarial_autoencoder.predict(x_test)
        yhat_inv = np.concatenate((x_test, yhat[0]), axis=1)
        yhat_inv = scaler.inverse_transform(yhat_inv)
        y3 = yhat_inv[:, 15:20]
        y_predall.append(y3[-3])

        # Here a_n+3 is at the last time level, only use to fit the transform
        y_next = np.concatenate(([y3[-3]], [y3[-2]], [y3[-1]], [y3[-1]]), axis=1)
        y_next = scaler.transform(y_next)
        y_next = y_next[:, :15]
        x_test = np.concatenate((x_test, [y_next[-1]]), axis=0)[-nstep:,:]
        
    return np.array(y_predall)

# %% [markdown]
# ### Start point = time step 100

# %%
n = 100
nstep_init = 19
npred = 100    # term = 35
time_level_pred = predict_next_time_level(x_train[n:nstep_init+n], nstep_init, npred)
times_pred = np.arange(0, (len(X_pod)+npred)*step, step, dtype="float64")
x_pred = np.concatenate((X_train[n:n+nstep_init, :5], time_level_pred), axis=0)

# %%
fig, ax = plt.subplots(1, 5, figsize=[22, 4])
for i in range(5):
    ax.flatten()[i].set_title("POD coeff. %d"%(i+1))
    ax.flatten()[i].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
    ax.flatten()[i].plot(times_pred[n:n+30], x_pred[:30,i],'-o')
    ax.flatten()[i].plot(times[n:n+30], X_train[n:n+30, i], '-o', alpha=0.7)
my_suptitle = plt.suptitle("(c) Prediction results with next time level method, starting at 2.5 × $10^1$ seconds.", y=-0.1, fontsize=16)
plt.savefig('images/AAE_next_100.png', dpi=300, bbox_inches='tight',bbox_extra_artists=[my_suptitle])

# %%
fig, ax = plt.subplots(2,1, figsize=[5,6])
ax[0].plot(times[n:n+30], X_pod[n:n+30]);
ax[0].grid()
ax[0].legend(range(5))

ax[1].plot(times_pred[n:n+30], x_pred[:30]);
ax[1].grid()
ax[1].legend(range(5))

# %% [markdown]
# Output as `csv`

# %%
out_dir = './../data/outputs/'
pod_coeffs_gen = np.transpose(x_pred)
np.savetxt(out_dir+'aae_next_100.csv', pod_coeffs_gen , delimiter=',')

# generate reconstructed pod coeffs
pod_basis = np.load(data_dir+'pod_basis_1.npy')
reconstructed = np.reshape((pod_basis[:,:5] @ pod_coeffs_gen), [1, 2, 221, 42, -1])

np.save(out_dir+'aae_next_100.npy', reconstructed)

# %% [markdown]
# Calculate error and relative error

# %%
X_true = X_pod[n:n+30]
X_pred = x_pred[:30]
error = X_pred-X_true
relative_error = error/X_true
plt.imshow(abs(error), aspect='auto', interpolation='None')
plt.colorbar(shrink=0.8)

# %%
fig, ax = plt.subplots(2,1, figsize=[15,6])
ax[0].plot(error);
ax[0].grid()
ax[0].legend(range(5),loc='lower left')

ax[1].plot(relative_error);
ax[1].grid()
ax[1].legend(range(5),loc='lower left')

# %% [markdown]
# Calculate prediction RMSE

# %%
# calculate RMSE
pred_mse = np.mean(tf.keras.losses.MSE(X_true, X_pred))
pred_rmse = np.sqrt(pred_mse)
#config.prediction_rmse = pred_rmse
print('Prediction RMSE: %.4f' % pred_rmse)
# Out:
# Prediction RMSE: 0.1060

# %% [markdown]
# ### Start point = time step 1000

# %%
n = 1000
nstep_init = 19
npred = 100    # term = 35
time_level_pred = predict_next_time_level(x_train[n:nstep_init+n], nstep_init, npred)
times_pred = np.arange(0, (len(X_pod)+npred)*step, step, dtype="float64")
x_pred = np.concatenate((X_train[n:n+nstep_init, :5], time_level_pred), axis=0)

# %%
fig, ax = plt.subplots(1, 5, figsize=[22, 4])
for i in range(5):
    ax.flatten()[i].set_title("POD coeff. %d"%(i+1))
    ax.flatten()[i].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
    ax.flatten()[i].plot(times_pred[n:n+30], x_pred[:30,i],'-o')
    ax.flatten()[i].plot(times[n:n+30], X_train[n:n+30, i], '-o', alpha=0.7)
my_suptitle = plt.suptitle("(d) Prediction results with next time level method, starting at 2.5 × $10^2$ seconds.", y=-0.1, fontsize=16)
plt.savefig('images/AAE_next_1000.png', dpi=300, bbox_inches='tight',bbox_extra_artists=[my_suptitle])

# %%
fig, ax = plt.subplots(2,1, figsize=[5,6])
ax[0].plot(times[n:n+30], X_pod[n:n+30]);
ax[0].grid()
ax[0].legend(range(5))

ax[1].plot(times_pred[n:n+30], x_pred[:30]);
ax[1].grid()
ax[1].legend(range(5))

# %% [markdown]
# Output as `csv`

# %%
out_dir = './../data/outputs/'
pod_coeffs_gen = np.transpose(x_pred)
np.savetxt(out_dir+'aae_next_1000.csv', pod_coeffs_gen , delimiter=',')

# generate reconstructed pod coeffs
pod_basis = np.load(data_dir+'pod_basis_1.npy')
reconstructed = np.reshape((pod_basis[:,:5] @ pod_coeffs_gen), [1, 2, 221, 42, -1])

np.save(out_dir+'aae_next_1000.npy', reconstructed)
# Out:
# wandb: Network error resolved after 0:00:29.020231, resuming normal operation.

# %% [markdown]
# Calculate error and relative error

# %%
X_true = X_pod[n:n+30]
X_pred = x_pred[:30]
error = X_pred-X_true
relative_error = error/X_true
plt.imshow(abs(error), aspect='auto', interpolation='None')
plt.colorbar(shrink=0.8)

# %%
fig, ax = plt.subplots(2,1, figsize=[15,6])
ax[0].plot(error);
ax[0].grid()
ax[0].legend(range(5),loc='lower left')

ax[1].plot(relative_error);
ax[1].grid()
ax[1].legend(range(5),loc='lower left')

# %% [markdown]
# Calculate prediction RMSE

# %%
# calculate RMSE
pred_mse = np.mean(tf.keras.losses.MSE(X_true, X_pred))
pred_rmse = np.sqrt(pred_mse)
#config.prediction_rmse = pred_rmse
print('Prediction RMSE: %.4f' % pred_rmse)
# Out:
# Prediction RMSE: 0.0492
