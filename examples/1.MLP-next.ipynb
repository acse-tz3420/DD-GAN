# %% [markdown]
# ===================================================
# ## 1. MLP-next
# #### a multi-layer perceptron (f) trained to predict the next time level $\alpha_{n+1} = f(\alpha_n)$
#
# #### Tianyi Zhao
# ===================================================

# %%
# %%javascript
# IPython.notebook.kernel.execute(`notebookName = '${IPython.notebook.notebook_name}'`)

# %%
notebookName
# Out:
# '1.POD-MLP-final-Copy1.ipynb'

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd
import time

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
tf.random.set_seed(42)
seed(42)

# %% [markdown]
# ## Load data

# %%
data_dir = './../data/single_domain/'
pod_coeffs = np.load(data_dir + 'pod_coeffs_1.npy') 
pod_coeffs.shape
# Out:
# (1, 10, 1999)

# %%
npod = 5
X_pod = np.transpose(pod_coeffs.reshape(10, 1999)[:npod])
step = 0.25
times = np.arange(0, len(X_pod)*step, step, dtype="float64")

X_pod.shape
# Out:
# (1999, 5)

# %%
fig, ax = plt.subplots(1,1, figsize=[15,3])
ax.plot(times[0:500], X_pod[0:500]);
ax.grid()
ax.legend(range(5),loc='lower left')

# %% [markdown]
# ## Prepare data

# %%
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Reconstruct the time series into a supervised learning dataset.
    input:
    data, list or array, sequence of observations
    n_in, int, length of lagging observations (X)
    n_out, int, length of observations (y)
    dropnan, boolean, discard rows with NaN values
    return:
    Pandas DataFrame, reconstructed dataset
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input series (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # predict series (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # concat column name with data
    agg = concat(cols, axis=1)
    agg.columns = names
    # discard rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# create dataset
dataset = DataFrame()
for i in range(5):
    dataset['ob%d'%i] = X_pod[:,i]
values = dataset.values
# make sure all values are float
values = values.astype('float32')
# Structured as a supervised learning problem
reframed = series_to_supervised(values, 1, 1)
# Normalized
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(reframed.values)
values = scaled

# %%
reframed.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)   var1(t)   var2(t)  \
# 1   3.788370   0.005678  -0.000566  -0.008302   0.009564  3.786842  0.005688
# 2   3.786842   0.005688  -0.000849  -0.008457   0.009378  3.786378  0.005678
# 3   3.786378   0.005678  -0.001172  -0.008663   0.009124  3.786565  0.005711
# 4   3.786565   0.005711  -0.001509  -0.008947   0.008888  3.787221  0.005720
# 5   3.787221   0.005720  -0.001844  -0.009363   0.008676  3.788207  0.005675
#
#     var3(t)   var4(t)   var5(t)
# 1 -0.000849 -0.008457  0.009378
# 2 -0.001172 -0.008663  0.009124
# 3 -0.001509 -0.008947  0.008888
# 4 -0.001844 -0.009363  0.008676
# 5 -0.002248 -0.009771  0.008444

# %%
# split train, validation and test set by 8:1:1
n_train = 1600
train = values[:n_train, :]
validation = values[n_train:n_train+200, :]
test = values[n_train+200:, :]
# create input and output
X_train, y_train = train[:, :5], train[:, 5:]
X_val, y_val = validation[:, :5], validation[:, 5:]
X_test, y_test = test[:, :5], test[:, 5:]
print(X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape)
# Out:
# (1600, 5) (1600, 5) (200, 5) (200, 5) (198, 5) (198, 5)

# %% [markdown]
# ## Train with MLP

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit


def plot_learning_curve(estimator, title, X, y, axes=None, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate 3 plots: the test and training learning curve, the training
    samples vs fit times curve, the fit times vs score curve.

    Parameters
    ----------
    estimator : estimator instance
        An estimator instance implementing `fit` and `predict` methods which
        will be cloned for each validation.

    title : str
        Title for the chart.

    X : array-like of shape (n_samples, n_features)
        Training vector, where ``n_samples`` is the number of samples and
        ``n_features`` is the number of features.

    y : array-like of shape (n_samples) or (n_samples, n_features)
        Target relative to ``X`` for classification or regression;
        None for unsupervised learning.

    axes : array-like of shape (3,), default=None
        Axes to use for plotting the curves.

    ylim : tuple of shape (2,), default=None
        Defines minimum and maximum y-values plotted, e.g. (ymin, ymax).

    cv : int, cross-validation generator or an iterable, default=None
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:

          - None, to use the default 5-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : int or None, default=None
        Number of jobs to run in parallel.
        ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.
        ``-1`` means using all processors. See :term:`Glossary <n_jobs>`
        for more details.

    train_sizes : array-like of shape (n_ticks,)
        Relative or absolute numbers of training examples that will be used to
        generate the learning curve. If the ``dtype`` is float, it is regarded
        as a fraction of the maximum size of the training set (that is
        determined by the selected validation method), i.e. it has to be within
        (0, 1]. Otherwise it is interpreted as absolute sizes of the training
        sets. Note that for classification the number of samples usually have
        to be big enough to contain at least one sample from each class.
        (default: np.linspace(0.1, 1.0, 5))
    """
    if axes is None:
        _, axes = plt.subplots(1, 3, figsize=(20, 5))

    axes[0].set_title(title)
    if ylim is not None:
        axes[0].set_ylim(*ylim)
    axes[0].set_xlabel("Training examples")
    axes[0].set_ylabel("Score")

    train_sizes, train_scores, test_scores, fit_times, _ = \
        learning_curve(estimator, X, y, cv=cv, n_jobs=n_jobs, 
                       train_sizes=train_sizes, return_times=True)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    fit_times_mean = np.mean(fit_times, axis=1)
    fit_times_std = np.std(fit_times, axis=1)

    # Plot learning curve
    axes[0].grid()
    axes[0].fill_between(train_sizes, train_scores_mean - train_scores_std,
                         train_scores_mean + train_scores_std, alpha=0.1,
                         color="r")
    axes[0].fill_between(train_sizes, test_scores_mean - test_scores_std,
                         test_scores_mean + test_scores_std, alpha=0.1,
                         color="g")
    axes[0].plot(train_sizes, train_scores_mean, 'o-', color="r",
                 label="Training score")
    axes[0].plot(train_sizes, test_scores_mean, 'o-', color="g",
                 label="Cross-validation score")
    axes[0].legend(loc="best")

    # Plot n_samples vs fit_times
    axes[1].grid()
    axes[1].plot(train_sizes, fit_times_mean, 'o-')
    axes[1].fill_between(train_sizes, fit_times_mean - fit_times_std,
                         fit_times_mean + fit_times_std, alpha=0.1)
    axes[1].set_xlabel("Training examples")
    axes[1].set_ylabel("fit_times")
    axes[1].set_title("Scalability of the model")

    # Plot fit_time vs score
    axes[2].grid()
    axes[2].plot(fit_times_mean, test_scores_mean, 'o-')
    axes[2].fill_between(fit_times_mean, test_scores_mean - test_scores_std,
                         test_scores_mean + test_scores_std, alpha=0.1)
    axes[2].set_xlabel("fit_times")
    axes[2].set_ylabel("Score")
    axes[2].set_title("Performance of the model")

    return plt

# %%
#fig, axes = plt.subplots(1, 3, figsize=(10, 15))

X, y = values[:, :5], values[:, 5:]

title = "Learning Curves (MLP_next)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)

estimator = MLPRegressor()
#estimator = model()
plot_learning_curve(estimator, title, X, y, axes=None, ylim=None,
                    cv=None, n_jobs=4)

plt.show()

# %% [raw]
# from tensorflow.keras import optimizers
# from tensorflow.keras.utils import plot_model
# from tensorflow.keras.models import Sequential, Model
# from tensorflow.keras.layers import Dense

# %%
epochs = 200
batch_size = 16
lr = 1e-3

# input_dim, input_length = input_shape(input_length, input_dim)
n_input = X_train.shape[1]
n_output = y_train.shape[1]

# %%
def make_mlp_model():
    model = tf.keras.Sequential()
    #model.add(Flatten(input_shape=X_train.shape))
    model.add(keras.layers.Dense(units=100, activation="relu", input_dim=n_input))    #units of hidden layer is 100
    model.add(keras.layers.Dense(units=100, activation="relu"))
    model.add(keras.layers.Dense(units=n_output))    #output layer, dim=n_output
    
    return model

# %%
mlp = make_mlp_model()
mlp.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               600
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 505
# =================================================================
# Total params: 11,205
# Trainable params: 11,205
# Non-trainable params: 0
# _________________________________________________________________

# %%
#mlp.built((None, 5))
keras.utils.plot_model(mlp,to_file='POD-MLP.png',show_shapes=True)

# %%
def plot_acc_loss(history):
    fig, ax = plt.subplots(1, 2, figsize=[12, 4])
    ax[0].grid()
    ax[0].plot(history['accuracy'],label='training acc')
    ax[0].plot(history['val_accuracy'],label='val acc')
    ax[0].set_title('model accuracy')
    ax[0].set_ylabel('accuracy')
    ax[0].set_xlabel('epoch')
    ax[0].legend(loc='lower right')
    
    ax[1].grid()
    ax[1].plot(history['loss'],label='training loss')
    ax[1].plot(history['val_loss'], label='val loss')
    ax[1].set_title('model loss')
    ax[1].set_yscale('log')
    ax[1].set_ylabel('loss')
    ax[1].set_xlabel('epoch')
    ax[1].legend(loc='lower right')

# %%
# fit model
optimizer = keras.optimizers.Adam(lr)
#reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, min_lr=lr*0.01)
mlp.compile(loss='mse', optimizer=optimizer, metrics=['accuracy'])
start = time.process_time()
mlp.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, 
          validation_data=(X_val, y_val), shuffle=False,
        initial_epoch=0)
elapsed = (time.process_time() - start)
# Out:
# Train on 1600 samples, validate on 200 samples
# Epoch 1/200
# 1600/1600 [==============================] - 1s 511us/sample - loss: 0.0389 - accuracy: 0.5063 - val_loss: 5.0289e-04 - val_accuracy: 0.9300
# Epoch 2/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 0.0012 - accuracy: 0.9312 - val_loss: 7.5401e-05 - val_accuracy: 0.9850
# Epoch 3/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 8.6880e-04 - accuracy: 0.9406 - val_loss: 3.2246e-05 - val_accuracy: 0.9900
# Epoch 4/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 6.9721e-04 - accuracy: 0.9481 - val_loss: 2.1229e-05 - val_accuracy: 0.9950
# Epoch 5/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 5.7795e-04 - accuracy: 0.9569 - val_loss: 1.6720e-05 - val_accuracy: 0.9950
# Epoch 6/200
# 1600/1600 [==============================] - 0s 89us/sample - loss: 4.9301e-04 - accuracy: 0.9644 - val_loss: 1.4974e-05 - val_accuracy: 0.9950
# Epoch 7/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 4.2531e-04 - accuracy: 0.9669 - val_loss: 1.3882e-05 - val_accuracy: 0.9950
# Epoch 8/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 3.7397e-04 - accuracy: 0.9694 - val_loss: 1.3321e-05 - val_accuracy: 0.9950
# Epoch 9/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 3.3218e-04 - accuracy: 0.9712 - val_loss: 1.2542e-05 - val_accuracy: 0.9950
# Epoch 10/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 3.0326e-04 - accuracy: 0.9712 - val_loss: 1.1913e-05 - val_accuracy: 0.9950
# Epoch 11/200
# 1600/1600 [==============================] - 0s 89us/sample - loss: 2.8337e-04 - accuracy: 0.9700 - val_loss: 1.1112e-05 - val_accuracy: 0.9950
# Epoch 12/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 2.6878e-04 - accuracy: 0.9694 - val_loss: 1.0162e-05 - val_accuracy: 0.9950
# Epoch 13/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 2.5799e-04 - accuracy: 0.9719 - val_loss: 9.1676e-06 - val_accuracy: 0.9950
# Epoch 14/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 2.4659e-04 - accuracy: 0.9725 - val_loss: 8.3328e-06 - val_accuracy: 0.9950
# Epoch 15/200
# 1600/1600 [==============================] - 0s 94us/sample - loss: 2.3895e-04 - accuracy: 0.9719 - val_loss: 7.6661e-06 - val_accuracy: 0.9950
# Epoch 16/200
# 1600/1600 [==============================] - 0s 89us/sample - loss: 2.3194e-04 - accuracy: 0.9731 - val_loss: 6.7957e-06 - val_accuracy: 0.9950
# Epoch 17/200
# 1600/1600 [==============================] - 0s 88us/sample - loss: 2.2442e-04 - accuracy: 0.9744 - val_loss: 6.5285e-06 - val_accuracy: 1.0000
# Epoch 18/200
# 1600/1600 [==============================] - 0s 88us/sample - loss: 2.1832e-04 - accuracy: 0.9744 - val_loss: 6.1194e-06 - val_accuracy: 1.0000
# Epoch 19/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 2.1054e-04 - accuracy: 0.9769 - val_loss: 5.5587e-06 - val_accuracy: 1.0000
# Epoch 20/200
# 1600/1600 [==============================] - 0s 88us/sample - loss: 2.0638e-04 - accuracy: 0.9775 - val_loss: 5.1952e-06 - val_accuracy: 1.0000
# Epoch 21/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 2.0029e-04 - accuracy: 0.9781 - val_loss: 4.8433e-06 - val_accuracy: 1.0000
# Epoch 22/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 1.9933e-04 - accuracy: 0.9787 - val_loss: 4.5931e-06 - val_accuracy: 0.9950
# Epoch 23/200
# 1600/1600 [==============================] - 0s 94us/sample - loss: 1.9496e-04 - accuracy: 0.9775 - val_loss: 4.4107e-06 - val_accuracy: 0.9950
# Epoch 24/200
# 1600/1600 [==============================] - 0s 88us/sample - loss: 1.9230e-04 - accuracy: 0.9800 - val_loss: 4.2424e-06 - val_accuracy: 1.0000
# Epoch 25/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 1.8774e-04 - accuracy: 0.9787 - val_loss: 4.0579e-06 - val_accuracy: 1.0000
# Epoch 26/200
# 1600/1600 [==============================] - 0s 88us/sample - loss: 1.8203e-04 - accuracy: 0.9775 - val_loss: 4.0209e-06 - val_accuracy: 1.0000
# Epoch 27/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 1.8559e-04 - accuracy: 0.9762 - val_loss: 3.8737e-06 - val_accuracy: 1.0000
# Epoch 28/200
# 1600/1600 [==============================] - 0s 88us/sample - loss: 1.7834e-04 - accuracy: 0.9756 - val_loss: 3.7858e-06 - val_accuracy: 1.0000
# Epoch 29/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 1.7493e-04 - accuracy: 0.9756 - val_loss: 3.6337e-06 - val_accuracy: 1.0000
# Epoch 30/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 1.7194e-04 - accuracy: 0.9775 - val_loss: 3.4932e-06 - val_accuracy: 1.0000
# Epoch 31/200
# 1600/1600 [==============================] - 0s 91us/sample - loss: 1.7122e-04 - accuracy: 0.9756 - val_loss: 3.4252e-06 - val_accuracy: 1.0000
# Epoch 32/200
# 1600/1600 [==============================] - 0s 89us/sample - loss: 1.7116e-04 - accuracy: 0.9769 - val_loss: 3.4118e-06 - val_accuracy: 1.0000
# Epoch 33/200
# 1600/1600 [==============================] - 0s 95us/sample - loss: 1.6797e-04 - accuracy: 0.9756 - val_loss: 3.3677e-06 - val_accuracy: 1.0000
# Epoch 34/200
# 1600/1600 [==============================] - 0s 96us/sample - loss: 1.6447e-04 - accuracy: 0.9762 - val_loss: 3.3578e-06 - val_accuracy: 1.0000
# Epoch 35/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 1.6181e-04 - accuracy: 0.9762 - val_loss: 3.3392e-06 - val_accuracy: 1.0000
# Epoch 36/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 1.6068e-04 - accuracy: 0.9744 - val_loss: 3.3452e-06 - val_accuracy: 1.0000
# Epoch 37/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 1.6215e-04 - accuracy: 0.9750 - val_loss: 3.3367e-06 - val_accuracy: 1.0000
# Epoch 38/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.5267e-04 - accuracy: 0.9750 - val_loss: 3.2615e-06 - val_accuracy: 1.0000
# Epoch 39/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.5715e-04 - accuracy: 0.9756 - val_loss: 3.3095e-06 - val_accuracy: 1.0000
# Epoch 40/200
# 1600/1600 [==============================] - 0s 88us/sample - loss: 1.5758e-04 - accuracy: 0.9762 - val_loss: 3.2862e-06 - val_accuracy: 1.0000
# Epoch 41/200
# 1600/1600 [==============================] - 0s 89us/sample - loss: 1.6373e-04 - accuracy: 0.9762 - val_loss: 3.3065e-06 - val_accuracy: 1.0000
# Epoch 42/200
# 1600/1600 [==============================] - 0s 106us/sample - loss: 1.6307e-04 - accuracy: 0.9775 - val_loss: 3.3261e-06 - val_accuracy: 1.0000
# Epoch 43/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.6190e-04 - accuracy: 0.9787 - val_loss: 3.4114e-06 - val_accuracy: 1.0000
# Epoch 44/200
# 1600/1600 [==============================] - 0s 92us/sample - loss: 1.5871e-04 - accuracy: 0.9769 - val_loss: 3.2934e-06 - val_accuracy: 1.0000
# Epoch 45/200
# 1600/1600 [==============================] - 0s 78us/sample - loss: 1.6862e-04 - accuracy: 0.9775 - val_loss: 3.5179e-06 - val_accuracy: 1.0000
# Epoch 46/200
# 1600/1600 [==============================] - 0s 89us/sample - loss: 1.6086e-04 - accuracy: 0.9762 - val_loss: 3.4223e-06 - val_accuracy: 1.0000
# Epoch 47/200
# 1600/1600 [==============================] - 0s 108us/sample - loss: 1.5842e-04 - accuracy: 0.9769 - val_loss: 3.6155e-06 - val_accuracy: 1.0000
# Epoch 48/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.5789e-04 - accuracy: 0.9737 - val_loss: 3.6574e-06 - val_accuracy: 1.0000
# Epoch 49/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.5902e-04 - accuracy: 0.9781 - val_loss: 3.5648e-06 - val_accuracy: 1.0000
# Epoch 50/200
# 1600/1600 [==============================] - 0s 106us/sample - loss: 1.4663e-04 - accuracy: 0.9787 - val_loss: 3.4310e-06 - val_accuracy: 1.0000
# Epoch 51/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.5885e-04 - accuracy: 0.9781 - val_loss: 3.3763e-06 - val_accuracy: 1.0000
# Epoch 52/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.5878e-04 - accuracy: 0.9756 - val_loss: 3.4511e-06 - val_accuracy: 1.0000
# Epoch 53/200
# 1600/1600 [==============================] - 0s 92us/sample - loss: 1.4867e-04 - accuracy: 0.9794 - val_loss: 3.3557e-06 - val_accuracy: 1.0000
# Epoch 54/200
# 1600/1600 [==============================] - 0s 97us/sample - loss: 1.5109e-04 - accuracy: 0.9781 - val_loss: 3.1827e-06 - val_accuracy: 1.0000
# Epoch 55/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.5619e-04 - accuracy: 0.9744 - val_loss: 3.3473e-06 - val_accuracy: 1.0000
# Epoch 56/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.5197e-04 - accuracy: 0.9800 - val_loss: 3.3754e-06 - val_accuracy: 1.0000
# Epoch 57/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.4649e-04 - accuracy: 0.9756 - val_loss: 3.3185e-06 - val_accuracy: 1.0000
# Epoch 58/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.5777e-04 - accuracy: 0.9806 - val_loss: 3.3761e-06 - val_accuracy: 1.0000
# Epoch 59/200
# 1600/1600 [==============================] - 0s 95us/sample - loss: 1.5627e-04 - accuracy: 0.9800 - val_loss: 3.2739e-06 - val_accuracy: 1.0000
# Epoch 60/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 1.4541e-04 - accuracy: 0.9787 - val_loss: 3.2025e-06 - val_accuracy: 1.0000
# Epoch 61/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.4459e-04 - accuracy: 0.9781 - val_loss: 3.1247e-06 - val_accuracy: 1.0000
# Epoch 62/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.5652e-04 - accuracy: 0.9750 - val_loss: 3.2290e-06 - val_accuracy: 1.0000
# Epoch 63/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.4842e-04 - accuracy: 0.9762 - val_loss: 3.0888e-06 - val_accuracy: 1.0000
# Epoch 64/200
# 1600/1600 [==============================] - 0s 94us/sample - loss: 1.3875e-04 - accuracy: 0.9756 - val_loss: 3.1217e-06 - val_accuracy: 1.0000
# Epoch 65/200
# 1600/1600 [==============================] - 0s 88us/sample - loss: 1.5844e-04 - accuracy: 0.9744 - val_loss: 3.1512e-06 - val_accuracy: 1.0000
# Epoch 66/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.4840e-04 - accuracy: 0.9769 - val_loss: 3.1773e-06 - val_accuracy: 1.0000
# Epoch 67/200
# 1600/1600 [==============================] - 0s 83us/sample - loss: 1.4676e-04 - accuracy: 0.9750 - val_loss: 3.2673e-06 - val_accuracy: 1.0000
# Epoch 68/200
# 1600/1600 [==============================] - 0s 83us/sample - loss: 1.4767e-04 - accuracy: 0.9750 - val_loss: 3.1509e-06 - val_accuracy: 1.0000
# Epoch 69/200
# 1600/1600 [==============================] - 0s 83us/sample - loss: 1.5933e-04 - accuracy: 0.9737 - val_loss: 3.4278e-06 - val_accuracy: 1.0000
# Epoch 70/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 1.3763e-04 - accuracy: 0.9769 - val_loss: 3.2544e-06 - val_accuracy: 1.0000
# Epoch 71/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 1.5076e-04 - accuracy: 0.9737 - val_loss: 3.3504e-06 - val_accuracy: 1.0000
# Epoch 72/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 1.4234e-04 - accuracy: 0.9775 - val_loss: 3.2444e-06 - val_accuracy: 1.0000
# Epoch 73/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 1.4747e-04 - accuracy: 0.9756 - val_loss: 3.4483e-06 - val_accuracy: 1.0000
# Epoch 74/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.4209e-04 - accuracy: 0.9769 - val_loss: 3.3440e-06 - val_accuracy: 1.0000
# Epoch 75/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.5049e-04 - accuracy: 0.9694 - val_loss: 3.4520e-06 - val_accuracy: 1.0000
# Epoch 76/200
# 1600/1600 [==============================] - 0s 91us/sample - loss: 1.3852e-04 - accuracy: 0.9775 - val_loss: 3.4527e-06 - val_accuracy: 1.0000
# Epoch 77/200
# 1600/1600 [==============================] - 0s 81us/sample - loss: 1.4113e-04 - accuracy: 0.9706 - val_loss: 3.4434e-06 - val_accuracy: 1.0000
# Epoch 78/200
# 1600/1600 [==============================] - 0s 83us/sample - loss: 1.4585e-04 - accuracy: 0.9719 - val_loss: 3.5038e-06 - val_accuracy: 1.0000
# Epoch 79/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.3638e-04 - accuracy: 0.9762 - val_loss: 3.4544e-06 - val_accuracy: 1.0000
# Epoch 80/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.3330e-04 - accuracy: 0.9756 - val_loss: 3.3564e-06 - val_accuracy: 1.0000
# Epoch 81/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 1.3768e-04 - accuracy: 0.9762 - val_loss: 3.4617e-06 - val_accuracy: 1.0000
# Epoch 82/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.3413e-04 - accuracy: 0.9756 - val_loss: 3.5601e-06 - val_accuracy: 1.0000
# Epoch 83/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.2840e-04 - accuracy: 0.9775 - val_loss: 3.4307e-06 - val_accuracy: 1.0000
# Epoch 84/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.2501e-04 - accuracy: 0.9775 - val_loss: 3.3445e-06 - val_accuracy: 1.0000
# Epoch 85/200
# 1600/1600 [==============================] - 0s 83us/sample - loss: 1.3600e-04 - accuracy: 0.9762 - val_loss: 3.5199e-06 - val_accuracy: 1.0000
# Epoch 86/200
# 1600/1600 [==============================] - 0s 83us/sample - loss: 1.1769e-04 - accuracy: 0.9781 - val_loss: 3.2979e-06 - val_accuracy: 1.0000
# Epoch 87/200
# 1600/1600 [==============================] - 0s 83us/sample - loss: 1.2322e-04 - accuracy: 0.9781 - val_loss: 3.4025e-06 - val_accuracy: 1.0000
# Epoch 88/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.2417e-04 - accuracy: 0.9787 - val_loss: 3.4468e-06 - val_accuracy: 1.0000
# Epoch 89/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.2439e-04 - accuracy: 0.9775 - val_loss: 3.4354e-06 - val_accuracy: 1.0000
# Epoch 90/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.1681e-04 - accuracy: 0.9800 - val_loss: 3.2491e-06 - val_accuracy: 1.0000
# Epoch 91/200
# 1600/1600 [==============================] - 0s 89us/sample - loss: 1.1653e-04 - accuracy: 0.9787 - val_loss: 3.2421e-06 - val_accuracy: 1.0000
# Epoch 92/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 1.2421e-04 - accuracy: 0.9775 - val_loss: 3.2895e-06 - val_accuracy: 1.0000
# Epoch 93/200
# 1600/1600 [==============================] - 0s 88us/sample - loss: 1.1390e-04 - accuracy: 0.9800 - val_loss: 3.1615e-06 - val_accuracy: 1.0000
# Epoch 94/200
# 1600/1600 [==============================] - 0s 101us/sample - loss: 1.1259e-04 - accuracy: 0.9787 - val_loss: 3.2386e-06 - val_accuracy: 1.0000
# Epoch 95/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.1929e-04 - accuracy: 0.9781 - val_loss: 3.2094e-06 - val_accuracy: 1.0000
# Epoch 96/200
# 1600/1600 [==============================] - 0s 95us/sample - loss: 1.1320e-04 - accuracy: 0.9794 - val_loss: 3.0424e-06 - val_accuracy: 1.0000
# Epoch 97/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 1.1046e-04 - accuracy: 0.9800 - val_loss: 3.0594e-06 - val_accuracy: 1.0000
# Epoch 98/200
# 1600/1600 [==============================] - 0s 89us/sample - loss: 1.1657e-04 - accuracy: 0.9787 - val_loss: 3.1988e-06 - val_accuracy: 1.0000
# Epoch 99/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.1604e-04 - accuracy: 0.9800 - val_loss: 3.1136e-06 - val_accuracy: 1.0000
# Epoch 100/200
# 1600/1600 [==============================] - 0s 88us/sample - loss: 1.1148e-04 - accuracy: 0.9806 - val_loss: 3.0648e-06 - val_accuracy: 1.0000
# Epoch 101/200
# 1600/1600 [==============================] - 0s 89us/sample - loss: 1.0887e-04 - accuracy: 0.9794 - val_loss: 3.0886e-06 - val_accuracy: 1.0000
# Epoch 102/200
# 1600/1600 [==============================] - 0s 107us/sample - loss: 1.1807e-04 - accuracy: 0.9756 - val_loss: 3.2351e-06 - val_accuracy: 1.0000
# Epoch 103/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 1.0917e-04 - accuracy: 0.9800 - val_loss: 3.3137e-06 - val_accuracy: 1.0000
# Epoch 104/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 1.0811e-04 - accuracy: 0.9787 - val_loss: 3.2238e-06 - val_accuracy: 1.0000
# Epoch 105/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.0827e-04 - accuracy: 0.9800 - val_loss: 3.3280e-06 - val_accuracy: 1.0000
# Epoch 106/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.1792e-04 - accuracy: 0.9800 - val_loss: 3.4572e-06 - val_accuracy: 1.0000
# Epoch 107/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.0585e-04 - accuracy: 0.9800 - val_loss: 3.2043e-06 - val_accuracy: 1.0000
# Epoch 108/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.0328e-04 - accuracy: 0.9800 - val_loss: 3.1683e-06 - val_accuracy: 1.0000
# Epoch 109/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.1498e-04 - accuracy: 0.9787 - val_loss: 3.3174e-06 - val_accuracy: 1.0000
# Epoch 110/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.0647e-04 - accuracy: 0.9781 - val_loss: 3.1307e-06 - val_accuracy: 1.0000
# Epoch 111/200
# 1600/1600 [==============================] - 0s 92us/sample - loss: 1.0436e-04 - accuracy: 0.9806 - val_loss: 3.1454e-06 - val_accuracy: 1.0000
# Epoch 112/200
# 1600/1600 [==============================] - 0s 91us/sample - loss: 1.0723e-04 - accuracy: 0.9781 - val_loss: 3.1154e-06 - val_accuracy: 1.0000
# Epoch 113/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 1.1176e-04 - accuracy: 0.9787 - val_loss: 3.1272e-06 - val_accuracy: 1.0000
# Epoch 114/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.0762e-04 - accuracy: 0.9806 - val_loss: 3.0216e-06 - val_accuracy: 1.0000
# Epoch 115/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 1.0585e-04 - accuracy: 0.9806 - val_loss: 2.8675e-06 - val_accuracy: 1.0000
# Epoch 116/200
# 1600/1600 [==============================] - 0s 91us/sample - loss: 1.1590e-04 - accuracy: 0.9769 - val_loss: 2.6591e-06 - val_accuracy: 1.0000
# Epoch 117/200
# 1600/1600 [==============================] - 0s 89us/sample - loss: 1.1064e-04 - accuracy: 0.9831 - val_loss: 2.6459e-06 - val_accuracy: 1.0000
# Epoch 118/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 1.0728e-04 - accuracy: 0.9806 - val_loss: 2.6094e-06 - val_accuracy: 1.0000
# Epoch 119/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.1614e-04 - accuracy: 0.9812 - val_loss: 2.7483e-06 - val_accuracy: 1.0000
# Epoch 120/200
# 1600/1600 [==============================] - 0s 88us/sample - loss: 1.1911e-04 - accuracy: 0.9819 - val_loss: 2.7828e-06 - val_accuracy: 1.0000
# Epoch 121/200
# 1600/1600 [==============================] - 0s 94us/sample - loss: 1.1847e-04 - accuracy: 0.9825 - val_loss: 2.5685e-06 - val_accuracy: 1.0000
# Epoch 122/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 1.2583e-04 - accuracy: 0.9825 - val_loss: 2.5936e-06 - val_accuracy: 1.0000
# Epoch 123/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.3191e-04 - accuracy: 0.9831 - val_loss: 2.7901e-06 - val_accuracy: 1.0000
# Epoch 124/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 1.3764e-04 - accuracy: 0.9837 - val_loss: 2.8888e-06 - val_accuracy: 1.0000
# Epoch 125/200
# 1600/1600 [==============================] - ETA: 0s - loss: 1.7059e-04 - accuracy: 0.98 - 0s 91us/sample - loss: 1.4059e-04 - accuracy: 0.9850 - val_loss: 3.0958e-06 - val_accuracy: 1.0000
# Epoch 126/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.3418e-04 - accuracy: 0.9844 - val_loss: 3.0274e-06 - val_accuracy: 1.0000
# Epoch 127/200
# 1600/1600 [==============================] - 0s 89us/sample - loss: 1.4128e-04 - accuracy: 0.9837 - val_loss: 3.1385e-06 - val_accuracy: 1.0000
# Epoch 128/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 1.3649e-04 - accuracy: 0.9837 - val_loss: 3.3795e-06 - val_accuracy: 1.0000
# Epoch 129/200
# 1600/1600 [==============================] - 0s 92us/sample - loss: 1.3210e-04 - accuracy: 0.9831 - val_loss: 3.2265e-06 - val_accuracy: 1.0000
# Epoch 130/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 1.2715e-04 - accuracy: 0.9837 - val_loss: 3.0170e-06 - val_accuracy: 1.0000
# Epoch 131/200
# 1600/1600 [==============================] - 0s 95us/sample - loss: 1.2953e-04 - accuracy: 0.9844 - val_loss: 3.0058e-06 - val_accuracy: 1.0000
# Epoch 132/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.1518e-04 - accuracy: 0.9825 - val_loss: 2.8308e-06 - val_accuracy: 1.0000
# Epoch 133/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.2264e-04 - accuracy: 0.9837 - val_loss: 2.8705e-06 - val_accuracy: 1.0000
# Epoch 134/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 1.0588e-04 - accuracy: 0.9837 - val_loss: 2.7597e-06 - val_accuracy: 1.0000
# Epoch 135/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.1813e-04 - accuracy: 0.9831 - val_loss: 2.8183e-06 - val_accuracy: 1.0000
# Epoch 136/200
# 1600/1600 [==============================] - 0s 89us/sample - loss: 1.0199e-04 - accuracy: 0.9844 - val_loss: 2.6211e-06 - val_accuracy: 1.0000
# Epoch 137/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.1828e-04 - accuracy: 0.9831 - val_loss: 2.8428e-06 - val_accuracy: 1.0000
# Epoch 138/200
# 1600/1600 [==============================] - 0s 103us/sample - loss: 9.9799e-05 - accuracy: 0.9856 - val_loss: 2.5708e-06 - val_accuracy: 1.0000
# Epoch 139/200
# 1600/1600 [==============================] - 0s 89us/sample - loss: 1.1725e-04 - accuracy: 0.9825 - val_loss: 2.7247e-06 - val_accuracy: 1.0000
# Epoch 140/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 9.6684e-05 - accuracy: 0.9844 - val_loss: 2.4069e-06 - val_accuracy: 1.0000
# Epoch 141/200
# 1600/1600 [==============================] - 0s 79us/sample - loss: 1.1158e-04 - accuracy: 0.9825 - val_loss: 2.5197e-06 - val_accuracy: 1.0000
# Epoch 142/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 9.5593e-05 - accuracy: 0.9825 - val_loss: 2.2868e-06 - val_accuracy: 1.0000
# Epoch 143/200
# 1600/1600 [==============================] - 0s 97us/sample - loss: 1.0454e-04 - accuracy: 0.9812 - val_loss: 2.3521e-06 - val_accuracy: 1.0000
# Epoch 144/200
# 1600/1600 [==============================] - 0s 100us/sample - loss: 9.5259e-05 - accuracy: 0.9825 - val_loss: 2.2400e-06 - val_accuracy: 1.0000
# Epoch 145/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 9.9265e-05 - accuracy: 0.9812 - val_loss: 2.2955e-06 - val_accuracy: 1.0000
# Epoch 146/200
# 1600/1600 [==============================] - 0s 104us/sample - loss: 9.8421e-05 - accuracy: 0.9825 - val_loss: 2.2606e-06 - val_accuracy: 1.0000
# Epoch 147/200
# 1600/1600 [==============================] - 0s 97us/sample - loss: 9.5934e-05 - accuracy: 0.9819 - val_loss: 2.2811e-06 - val_accuracy: 1.0000
# Epoch 148/200
# 1600/1600 [==============================] - 0s 92us/sample - loss: 9.8601e-05 - accuracy: 0.9831 - val_loss: 2.2971e-06 - val_accuracy: 1.0000
# Epoch 149/200
# 1600/1600 [==============================] - 0s 103us/sample - loss: 9.5681e-05 - accuracy: 0.9825 - val_loss: 2.3287e-06 - val_accuracy: 1.0000
# Epoch 150/200
# 1600/1600 [==============================] - 0s 100us/sample - loss: 9.9871e-05 - accuracy: 0.9819 - val_loss: 2.2953e-06 - val_accuracy: 1.0000
# Epoch 151/200
# 1600/1600 [==============================] - 0s 95us/sample - loss: 1.0020e-04 - accuracy: 0.9819 - val_loss: 2.5293e-06 - val_accuracy: 1.0000
# Epoch 152/200
# 1600/1600 [==============================] - 0s 96us/sample - loss: 9.9710e-05 - accuracy: 0.9825 - val_loss: 2.3991e-06 - val_accuracy: 1.0000
# Epoch 153/200
# 1600/1600 [==============================] - 0s 101us/sample - loss: 9.6443e-05 - accuracy: 0.9831 - val_loss: 2.4464e-06 - val_accuracy: 1.0000
# Epoch 154/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 1.0279e-04 - accuracy: 0.9837 - val_loss: 2.5710e-06 - val_accuracy: 1.0000
# Epoch 155/200
# 1600/1600 [==============================] - 0s 95us/sample - loss: 9.6642e-05 - accuracy: 0.9825 - val_loss: 2.6138e-06 - val_accuracy: 1.0000
# Epoch 156/200
# 1600/1600 [==============================] - 0s 101us/sample - loss: 1.0015e-04 - accuracy: 0.9831 - val_loss: 2.6351e-06 - val_accuracy: 1.0000
# Epoch 157/200
# 1600/1600 [==============================] - 0s 101us/sample - loss: 1.0572e-04 - accuracy: 0.9831 - val_loss: 2.7572e-06 - val_accuracy: 1.0000
# Epoch 158/200
# 1600/1600 [==============================] - 0s 92us/sample - loss: 9.8762e-05 - accuracy: 0.9825 - val_loss: 2.6361e-06 - val_accuracy: 1.0000
# Epoch 159/200
# 1600/1600 [==============================] - 0s 91us/sample - loss: 1.0652e-04 - accuracy: 0.9837 - val_loss: 2.6535e-06 - val_accuracy: 1.0000
# Epoch 160/200
# 1600/1600 [==============================] - 0s 94us/sample - loss: 1.0983e-04 - accuracy: 0.9812 - val_loss: 2.6508e-06 - val_accuracy: 1.0000
# Epoch 161/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 1.0543e-04 - accuracy: 0.9825 - val_loss: 2.5912e-06 - val_accuracy: 1.0000
# Epoch 162/200
# 1600/1600 [==============================] - 0s 99us/sample - loss: 1.2698e-04 - accuracy: 0.9831 - val_loss: 2.6202e-06 - val_accuracy: 1.0000
# Epoch 163/200
# 1600/1600 [==============================] - 0s 92us/sample - loss: 1.1452e-04 - accuracy: 0.9812 - val_loss: 2.5758e-06 - val_accuracy: 1.0000
# Epoch 164/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 1.1872e-04 - accuracy: 0.9819 - val_loss: 2.5336e-06 - val_accuracy: 1.0000
# Epoch 165/200
# 1600/1600 [==============================] - 0s 95us/sample - loss: 1.3393e-04 - accuracy: 0.9837 - val_loss: 2.6486e-06 - val_accuracy: 1.0000
# Epoch 166/200
# 1600/1600 [==============================] - 0s 92us/sample - loss: 1.2323e-04 - accuracy: 0.9800 - val_loss: 2.6798e-06 - val_accuracy: 1.0000
# Epoch 167/200
# 1600/1600 [==============================] - 0s 91us/sample - loss: 1.3112e-04 - accuracy: 0.9819 - val_loss: 2.8319e-06 - val_accuracy: 1.0000
# Epoch 168/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 1.4011e-04 - accuracy: 0.9806 - val_loss: 3.3098e-06 - val_accuracy: 1.0000
# Epoch 169/200
# 1600/1600 [==============================] - 0s 99us/sample - loss: 1.4090e-04 - accuracy: 0.9800 - val_loss: 3.6909e-06 - val_accuracy: 1.0000
# Epoch 170/200
# 1600/1600 [==============================] - 0s 99us/sample - loss: 1.5173e-04 - accuracy: 0.9800 - val_loss: 4.0938e-06 - val_accuracy: 1.0000
# Epoch 171/200
# 1600/1600 [==============================] - 0s 94us/sample - loss: 1.7688e-04 - accuracy: 0.9750 - val_loss: 4.1637e-06 - val_accuracy: 1.0000
# Epoch 172/200
# 1600/1600 [==============================] - 0s 94us/sample - loss: 1.5741e-04 - accuracy: 0.9756 - val_loss: 3.7116e-06 - val_accuracy: 1.0000
# Epoch 173/200
# 1600/1600 [==============================] - 0s 94us/sample - loss: 1.7201e-04 - accuracy: 0.9744 - val_loss: 3.6601e-06 - val_accuracy: 1.0000
# Epoch 174/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 2.0902e-04 - accuracy: 0.9731 - val_loss: 4.0068e-06 - val_accuracy: 1.0000
# Epoch 175/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.9080e-04 - accuracy: 0.9719 - val_loss: 3.8106e-06 - val_accuracy: 1.0000
# Epoch 176/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.7747e-04 - accuracy: 0.9762 - val_loss: 3.7005e-06 - val_accuracy: 1.0000
# Epoch 177/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 2.0062e-04 - accuracy: 0.9744 - val_loss: 4.0364e-06 - val_accuracy: 1.0000
# Epoch 178/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 2.1675e-04 - accuracy: 0.9694 - val_loss: 4.5475e-06 - val_accuracy: 1.0000
# Epoch 179/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.8048e-04 - accuracy: 0.9787 - val_loss: 5.3345e-06 - val_accuracy: 1.0000
# Epoch 180/200
# 1600/1600 [==============================] - 0s 85us/sample - loss: 1.9753e-04 - accuracy: 0.9775 - val_loss: 7.1555e-06 - val_accuracy: 1.0000
# Epoch 181/200
# 1600/1600 [==============================] - 0s 93us/sample - loss: 1.8572e-04 - accuracy: 0.9794 - val_loss: 8.0810e-06 - val_accuracy: 1.0000
# Epoch 182/200
# 1600/1600 [==============================] - 0s 91us/sample - loss: 2.0300e-04 - accuracy: 0.9769 - val_loss: 9.8293e-06 - val_accuracy: 0.9900
# Epoch 183/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 1.8551e-04 - accuracy: 0.9775 - val_loss: 1.0840e-05 - val_accuracy: 0.9950
# Epoch 184/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.8599e-04 - accuracy: 0.9781 - val_loss: 1.2452e-05 - val_accuracy: 0.9900
# Epoch 185/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.7806e-04 - accuracy: 0.9781 - val_loss: 1.2329e-05 - val_accuracy: 0.9900
# Epoch 186/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 1.8408e-04 - accuracy: 0.9756 - val_loss: 1.2507e-05 - val_accuracy: 0.9900
# Epoch 187/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 1.6267e-04 - accuracy: 0.9756 - val_loss: 1.2001e-05 - val_accuracy: 0.9900
# Epoch 188/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 1.7271e-04 - accuracy: 0.9769 - val_loss: 1.1502e-05 - val_accuracy: 0.9900
# Epoch 189/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.6389e-04 - accuracy: 0.9750 - val_loss: 1.0757e-05 - val_accuracy: 0.9900
# Epoch 190/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.6317e-04 - accuracy: 0.9762 - val_loss: 9.7293e-06 - val_accuracy: 0.9900
# Epoch 191/200
# 1600/1600 [==============================] - 0s 101us/sample - loss: 1.4953e-04 - accuracy: 0.9769 - val_loss: 9.4835e-06 - val_accuracy: 0.9900
# Epoch 192/200
# 1600/1600 [==============================] - 0s 86us/sample - loss: 1.5184e-04 - accuracy: 0.9800 - val_loss: 8.8097e-06 - val_accuracy: 0.9900
# Epoch 193/200
# 1600/1600 [==============================] - 0s 84us/sample - loss: 1.4879e-04 - accuracy: 0.9781 - val_loss: 9.0303e-06 - val_accuracy: 0.9900
# Epoch 194/200
# 1600/1600 [==============================] - 0s 83us/sample - loss: 1.4474e-04 - accuracy: 0.9794 - val_loss: 8.5691e-06 - val_accuracy: 0.9900
# Epoch 195/200
# 1600/1600 [==============================] - 0s 83us/sample - loss: 1.4745e-04 - accuracy: 0.9794 - val_loss: 8.6747e-06 - val_accuracy: 0.9900
# Epoch 196/200
# 1600/1600 [==============================] - 0s 83us/sample - loss: 1.4146e-04 - accuracy: 0.9794 - val_loss: 8.4562e-06 - val_accuracy: 0.9900
# Epoch 197/200
# 1600/1600 [==============================] - 0s 83us/sample - loss: 1.4533e-04 - accuracy: 0.9806 - val_loss: 8.5856e-06 - val_accuracy: 0.9900
# Epoch 198/200
# 1600/1600 [==============================] - 0s 83us/sample - loss: 1.4620e-04 - accuracy: 0.9806 - val_loss: 8.5119e-06 - val_accuracy: 0.9900
# Epoch 199/200
# 1600/1600 [==============================] - 0s 90us/sample - loss: 1.4848e-04 - accuracy: 0.9794 - val_loss: 8.6671e-06 - val_accuracy: 0.9900
# Epoch 200/200
# 1600/1600 [==============================] - 0s 87us/sample - loss: 1.4334e-04 - accuracy: 0.9794 - val_loss: 8.7202e-06 - val_accuracy: 0.9900

# %%
print("Training time:",elapsed)
# Out:
# Training time: 50.875

# %%
plot_acc_loss(mlp.history.history)

# %%
import joblib
joblib.dump(scaler, "models/scaler-mpl-next.pkl")
mlp.save("models/mlp-next.h5")

# %% [markdown]
# ## Predict one next time level on test set

# %% [raw]
# from tensorflow.keras.models import load_model
# import joblib
#
# model_name = 'models/mlp-next.h5'
# mlp = load_model('./{model_name}'.format(model_name=model_name)).layers
# scaler = joblib.load("models/scaler-mlp-next.pkl")

# %%
# make prediction
yhat = mlp.predict(X_test)
# Inverse scaling predicted value
yhat_inv = np.concatenate((X_test, yhat), axis=1)
yhat_inv = scaler.inverse_transform(yhat_inv)
yhat_inv = yhat_inv[:, 5:]
# Inverse scaling true value
y_inv = scaler.inverse_transform(test)
y_inv = y_inv[:, 5:]
# calculate RMSE
rmse = np.sqrt(mean_squared_error(y_inv, yhat_inv))
print('Test RMSE of next time level: %.3f' % rmse)
# Out:
# Test RMSE of next time level: 0.003

# %%
fig, ax = plt.subplots(1, 5, figsize=[22, 4])
for i in range(5):
    ax.flatten()[i].plot(times[1800:-1], yhat_inv[:,i],'-o')
    ax.flatten()[i].plot(times[1800:-1], y_inv[:,i], '-o')

# %% [markdown]
# ## Predict multiple time levels

# %%
def predict_next_time_level(x_test, x_inv, nstep, npredict):
    y_predall = []
    for i in range(npredict):
        yhat = mlp.predict(x_test)
        yhat_inv = np.concatenate((x_test, yhat), axis=1)
        yhat_inv = scaler.inverse_transform(yhat_inv)
        yhat_inv = yhat_inv[:, 5:]
        y_predall.append(yhat_inv[-1])
        #y_pred = step * yhat_inv + x_inv

        y_next = np.concatenate((yhat_inv, x_inv), axis=1)
        y_next = scaler.transform(y_next)
        y_next = y_next[:, :5]
        x_test = np.concatenate((x_test, [y_next[-1]]), axis=0)[-nstep:,:]
        x_inv = np.concatenate((x_inv, [yhat_inv[-1]]), axis=0)[-nstep:,:]
        
    return np.array(y_predall)

# %% [markdown]
# ### Start point = time step 500

# %%
n = 500
nstep_init = 5
npredict = 100    # term = 35
time_level_pred = predict_next_time_level(values[n-nstep_init:n, :5], reframed.values[n-nstep_init:n, :5], nstep_init, npredict)
times_pred = np.arange(0, (len(X_pod)+npredict)*step, step, dtype="float64")

# %%
fig, ax = plt.subplots(1, 5, figsize=[22, 4])
for i in range(5):
    ax.flatten()[i].plot(times_pred[n:n+npredict], time_level_pred[:,i],'-o')
    ax.flatten()[i].plot(times[n:n+npredict], reframed.values[n:n+npredict, i], '-o', alpha=0.7)

# %% [markdown]
# ### Start point = time step 1000

# %%
n = 1000
nstep_init = 5
npredict = 100    # term = 35
time_level_pred = predict_next_time_level(values[n-nstep_init:n, :5], reframed.values[n-nstep_init:n, :5], nstep_init, npredict)
times_pred = np.arange(0, (len(X_pod)+npredict)*step, step, dtype="float64")

# %%
fig, ax = plt.subplots(1, 5, figsize=[22, 4])
for i in range(5):
    ax.flatten()[i].plot(times_pred[n:n+npredict], time_level_pred[:,i],'-o')
    ax.flatten()[i].plot(times[n:n+npredict], reframed.values[n:n+npredict, i], '-o', alpha=0.7)

# %% [markdown]
# ## Predict the whole simulation

# %% [markdown]
# ### Start point = time step 100

# %%
n = 100
nstep_init = 19
npredict = 1000    # term = 35
start = time.process_time()
time_level_pred = predict_next_time_level(values[n:nstep_init+n, :5], reframed.values[n:nstep_init+n, :5], nstep_init, npredict)
times_pred = np.arange(0, (len(X_pod)+npredict)*step, step, dtype="float64")
elapsed = (time.process_time() - start)
print("Predicting time:",elapsed)
x_pred = np.concatenate((reframed.values[n:nstep_init+n, :5], time_level_pred), axis=0)
# Out:
# Predicting time: 45.0625

# %%
fig, ax = plt.subplots(5, 1, figsize=[15, 8])
for i in range(5):
    ax.flatten()[i].set_title("POD coeff. %d"%(i+1))
    ax.flatten()[i].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
    ax.flatten()[i].plot(times_pred[n:n+nstep_init+npredict], x_pred[:,i])
    ax.flatten()[i].plot(times[n:n+nstep_init+npredict], reframed.values[n:n+nstep_init+npredict, i], alpha=0.7)
plt.tight_layout()
my_suptitle = plt.suptitle("(b) Prediction results with next time level method, starting at 2.5 × $10^1$ seconds.", y=-0.1, fontsize=16)
plt.savefig('MLP_next_100.png', dpi=300, bbox_inches='tight',bbox_extra_artists=[my_suptitle])

# %% [markdown]
# ### Start point = time step 1000

# %%
n = 1000
nstep_init = 19
npredict = 1000    # term = 35
start = time.process_time()
time_level_pred = predict_next_time_level(values[n:nstep_init+n, :5], reframed.values[n:nstep_init+n, :5], nstep_init, npredict)
times_pred = np.arange(0, (len(X_pod)+npredict)*step, step, dtype="float64")
elapsed = (time.process_time() - start)
print("Predicting time:",elapsed)
x_pred = np.concatenate((reframed.values[n:nstep_init+n, :5], time_level_pred), axis=0)
# Out:
# Predicting time: 50.953125

# %%
fig, ax = plt.subplots(5, 1, figsize=[15, 8])
for i in range(5):
    ax.flatten()[i].set_title("POD coeff. %d"%(i+1))
    ax.flatten()[i].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
    ax.flatten()[i].plot(times_pred[n:n+nstep_init+npredict], x_pred[:,i])
    ax.flatten()[i].plot(times[n:-1], reframed.values[n:, i], alpha=0.7)
plt.tight_layout()
my_suptitle = plt.suptitle("(b) Prediction results with next time level method, starting at 2.5 × $10^2$ seconds.", y=-0.1, fontsize=16)
plt.savefig('MLP_next_1000.png', dpi=300, bbox_inches='tight',bbox_extra_artists=[my_suptitle])

# %%
fig, ax = plt.subplots(2,1, figsize=[15,6])
ax[0].plot(times[n:-1], reframed.values[n:, :5]);
ax[0].grid()
ax[0].legend(range(5))

ax[1].plot(times_pred[n:n+nstep_init+npredict], x_pred);
ax[1].grid()
ax[1].legend(range(5))

# %% [markdown]
# Output as `csv`

# %%
out_dir = 'outputs/'
pod_coeffs_gen = np.transpose(x_pred)
np.savetxt(out_dir+'mlp_next_1000.csv', pod_coeffs_gen , delimiter=',')

# generate reconstructed pod coeffs
pod_basis = np.load(data_dir+'pod_basis_1.npy')
reconstructed = np.reshape((pod_basis[:,:5] @ pod_coeffs_gen), [1, 2, 221, 42, -1])

np.save(out_dir+'mlp_next_1000.npy', reconstructed)

# %% [markdown]
# Calculate error and relative error

# %%
X_true = reframed.values[n:, :5]
X_pred = x_pred[:998]
error = X_pred-X_true
relative_error = error/X_true
plt.imshow(abs(error), aspect='auto', interpolation='None')
plt.colorbar(shrink=0.8)

# %%
fig, ax = plt.subplots(2,1, figsize=[15,6])
ax[0].plot(error);
ax[0].grid()
ax[0].legend(range(5),loc='lower left')

ax[1].plot(relative_error);
ax[1].grid()
ax[1].legend(range(5),loc='lower left')

# %% [markdown]
# Calculate prediction RMSE

# %%
# calculate RMSE
pred_mse = np.mean(tf.keras.losses.MSE(X_true, X_pred))
pred_rmse = np.sqrt(pred_mse)
#config.prediction_rmse = pred_rmse
print('Prediction RMSE: %.4f' % pred_rmse)
# Out:
# Prediction RMSE: 0.1115

# %% [markdown]
# ## Predict beyond simulation

# %% [markdown]
# ### Start point = time step 1800

# %%
n = 1800
nstep_init = 5
npredict = 1000    # term = 35
start = time.process_time()
time_level_pred = predict_next_time_level(values[n-nstep_init:n, :5], reframed.values[n-nstep_init:n, :5], nstep_init, npredict)
times_pred = np.arange(0, (len(X_pod)+npredict)*step, step, dtype="float64")
elapsed = (time.process_time() - start)
print("Predicting time:",elapsed)
# Out:
# Predicting time: 43.359375

# %%
fig, ax = plt.subplots(5,1, figsize=[15,8])
for i in range(5):      
    ax.flatten()[i].plot(times_pred[n:n+npredict], time_level_pred[:,i])
    ax.flatten()[i].plot(times[n:-1], reframed.values[n:, i], alpha=0.9)
    
plt.tight_layout()
#plt.savefig('GAN_0-end_p4.png')
